# %%
from Functions import script

# %% [markdown]
# Step1 >> Determine Script requirements

# %%
covied = script(script_Name="Covied19",api="https://coronavirus.m.pipedream.net",data_section="rawData")

# %% [markdown]
# Step2 >> which columns do you need  ? choose how many columns and assign it

# %%
covied.assign_columns_Func()
# Out:
# Column 1 assigned to Country_Region
# Column 2 assigned to Province_State
# Column 3 assigned to Confirmed
# Column 4 assigned to Deaths

# %% [markdown]
# show columns list

# %%
covied.show_columns_list()
# Out:
# column no.:  1 | column name: Country_Region
# column no.:  2 | column name: Province_State
# column no.:  3 | column name: Confirmed
# column no.:  4 | column name: Deaths

# %% [markdown]
# Step3 >>> print Data

# %%
covied.View_data_as_a_print()
# Out:
# Afghanistan    |        |    175893    |    7639    |
# Albania    |        |    272479    |    3484    |
# Algeria    |        |    265366    |    6861    |
# Andorra    |        |    38794    |    152    |
# Angola    |        |    98855    |    1900    |
# Antarctica    |        |    11    |    0    |
# Antigua and Barbuda    |        |    7461    |    135    |
# Argentina    |        |    8961595    |    127009    |
# Armenia    |        |    421714    |    8563    |
# Australia    |    Australian Capital Territory    |    58021    |    37    |
# Australia    |    New South Wales    |    1435768    |    1971    |
# Australia    |    Northern Territory    |    44513    |    33    |
# Australia    |    Queensland    |    616937    |    623    |
# Australia    |    South Australia    |    170346    |    219    |
# Australia    |    Tasmania    |    55696    |    26    |
# Australia    |    Victoria    |    1112363    |    2629    |
# ...

# %% [markdown]
# Step4 >>> Export CSV File

# %%
covied.Save_To_Csv_file()
# Out:
# Done , Exported file Covied19_File.csv including 15864 full informations and 176 empty informations

# %% [markdown]
# Step 5 >>> Show data in table with pandas module

# %%
covied.get_table_show_panda()
# Out:
#             Country_Region Province_State  Confirmed  Deaths
# 0              Afghanistan            NaN     175893    7639
# 1                  Albania            NaN     272479    3484
# 2                  Algeria            NaN     265366    6861
# 3                  Andorra            NaN      38794     152
# 4                   Angola            NaN      98855    1900
# ...                    ...            ...        ...     ...
# 4005    West Bank and Gaza            NaN     652966    5594
# 4006  Winter Olympics 2022            NaN        535       0
# 4007                 Yemen            NaN      11783    2139
# 4008                Zambia            NaN     314850    3960
# 4009              Zimbabwe            NaN     241548    5408
#
# [4010 rows x 4 columns]
